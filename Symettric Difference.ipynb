# %%
def func():
    m=int(input())
    a=set(list(map(int,input().split())))
    n=int(input())
    b=set(list(map(int,input().split())))
    c=a.difference(b)
    d=b.difference(a)
    e=list(c.union(d))
    e.sort()
    print(*e,sep='\n')
func()
# Out:
# 4
# 2 4 5 9
# 4
# 2 4 11 12
# 2
# 4
# 5
# 9
# 11
# 12
